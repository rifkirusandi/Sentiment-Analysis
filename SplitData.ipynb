# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Load the dataset
columns = 'review scores compound sentiment'.split() # Declare the columns names

df = pd.read_csv('canggu_preprocessed.csv')
# df.head()

canggu_train, canggu_test = train_test_split(df, test_size=0.2, random_state=0)

# print(f"No. of training examples: {doublesix_train.shape[0]}")
# print(f"No. of testing examples: {doublesix_test.shape[0]}")

# %%
canggu_train.to_csv('canggu_train.csv', index=False, encoding='utf-8')
canggu_test.to_csv('canggu_test.csv', index=False, encoding='utf-8')
