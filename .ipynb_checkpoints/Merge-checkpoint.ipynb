# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import glob

# %%
interesting_files = glob.glob("*_train_30.csv") 
df = pd.concat((pd.read_csv(f, header = 0) for f in interesting_files)).astype("str")
df.to_csv('data_train_30.csv', index=False, encoding='utf-8')

# %%
len(df)
# Out:
# 3192
